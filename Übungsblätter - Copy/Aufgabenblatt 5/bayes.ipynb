# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

model_gauss = GaussianNB()

model_gauss.fit(X_train, y_train)
model_gauss.score(X_test, y_test)

y_pred = model_gauss.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[29,  0,  0],
#        [ 0, 23,  0],
#        [ 0,  1, 22]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        model_gauss,
        X_test,
        y_test,
        display_labels=list(load_iris().target_names),
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Confusion matrix, without normalization
# [[29  0  0]
#  [ 0 23  0]
#  [ 0  1 22]]
# Normalized confusion matrix
# [[1.         0.         0.        ]
#  [0.         1.         0.        ]
#  [0.         0.04347826 0.95652174]]

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

X, y = load_wine(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

model_gauss = GaussianNB()

model_gauss.fit(X_train, y_train)
model_gauss.score(X_test, y_test)

y_pred = model_gauss.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[32,  1,  0],
#        [ 0, 34,  0],
#        [ 0,  0, 22]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        model_gauss,
        X_test,
        y_test,
        display_labels=list(load_wine().target_names),
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Confusion matrix, without normalization
# [[32  1  0]
#  [ 0 34  0]
#  [ 0  0 22]]
# Normalized confusion matrix
# [[0.96969697 0.03030303 0.        ]
#  [0.         1.         0.        ]
#  [0.         0.         1.        ]]

# %%
from sklearn.datasets import make_moons
X, y = make_moons(1000, noise=0.8)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

model_gauss = GaussianNB()

model_gauss.fit(X_train, y_train)
model_gauss.score(X_test, y_test)

y_pred = model_gauss.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[183,  68],
#        [ 74, 175]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        model_gauss,
        X_test,
        y_test,
        display_labels=[0,1],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Confusion matrix, without normalization
# [[183  68]
#  [ 74 175]]
# Normalized confusion matrix
# [[0.72908367 0.27091633]
#  [0.29718876 0.70281124]]
